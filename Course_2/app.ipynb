# %%
import os
import cv2
import numpy as np
from skimage.filters import gabor

# 指定数据集的根目录
dataset_root = 'Dataset'
output_root = 'output'

# 创建输出文件夹
if not os.path.exists(output_root):
    os.makedirs(output_root)

def gabor_kernel(ksize, sigma, gamma, lamda, alpha, psi):
    sigma_x = sigma
    sigma_y = sigma / gamma

    ymax = xmax = ksize // 2  # 9//2
    xmin, ymin = -xmax, -ymax

    (y, x) = np.meshgrid(np.arange(ymin, ymax + 1), np.arange(xmin, xmax + 1))  # 生成网格点坐标矩阵
    x_alpha = x * np.cos(alpha) + y * np.sin(alpha)
    y_alpha = -x * np.sin(alpha) + y * np.cos(alpha)
    exponent = np.exp(-.5 * (x_alpha ** 2 / sigma_x ** 2 + y_alpha ** 2 / sigma_y ** 2))
    kernel = exponent * np.cos(2 * np.pi / lamda * x_alpha + psi)
    return kernel


def gabor(gray_img, ksize=9, sigma=1.0, gamma=0.5, lamda=5, psi=-np.pi/2):#gabor滤波
    filters = []
    for alpha in np.arange(0, np.pi, np.pi / 4):
        kern = gabor_kernel(ksize=ksize, sigma=sigma, gamma=gamma,lamda=lamda, alpha=alpha, psi=psi)
        filters.append(kern)

    gabor_img = np.zeros(gray_img.shape, dtype=np.uint8)

    i = 0
    for kern in filters:
        fimg = cv2.filter2D(gray_img, ddepth=cv2.CV_8U, kernel=kern)
        gabor_img = cv2.max(gabor_img, fimg)
        i += 1

    return gabor_img


# 遍历子文件夹
for person_folder in os.listdir(dataset_root):
    person_folder_path = os.path.join(dataset_root, person_folder)

    # 确保当前路径是一个文件夹
    if os.path.isdir(person_folder_path):
        print(f"Processing images in folder: {person_folder}")

        # 创建当前人的输出文件夹
        output_person_folder = os.path.join(output_root, person_folder)
        if not os.path.exists(output_person_folder):
            os.makedirs(output_person_folder)

        # 遍历文件夹中的图像文件
        for image_file in os.listdir(person_folder_path):
            image_path = os.path.join(person_folder_path, image_file)

            # 读取图像
            image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

            # image = cv2.equalizeHist(image)

            # 检查图像是否成功加载
            if image is None:
                print(f"Error loading the image {image_file}. Please check the image path.")
                continue

            # 应用Gabor滤波器到图像
            gabor_result = gabor(image, ksize=9, sigma=1.0, gamma=0.5, lamda=5, psi=-np.pi/2)

            # 对Gabor滤波结果应用拉普拉斯算子
            laplacian_result = cv2.Laplacian(gabor_result, cv2.CV_32F)

            # 调整对比度
            alpha = 2.5  # 调整因子，可以根据需要调整
            adjusted_image = cv2.convertScaleAbs(laplacian_result, alpha=alpha, beta=0)

            ksize = 5
            blurred_img = cv2.GaussianBlur(adjusted_image, (ksize, ksize), sigmaX=5)

            # 二值化图像
            _, binary_img = cv2.threshold(blurred_img, 54, 255, cv2.THRESH_BINARY)

            kernel = np.ones((3, 3), np.uint8)
            opened_img = cv2.morphologyEx(binary_img, cv2.MORPH_OPEN, kernel, iterations=1)

            # 保存处理后的图像到输出文件夹
            output_image_path = os.path.join(output_person_folder, image_file)
            cv2.imwrite(output_image_path, opened_img)

# 提示处理完成
print("Image processing and saving completed.")
# Out:
# Processing images in folder: 001
# Processing images in folder: 002
# Processing images in folder: 003
# Processing images in folder: 004
# Processing images in folder: 005
# Processing images in folder: 006
# Processing images in folder: 007
# Processing images in folder: 008
# Processing images in folder: 009
# Processing images in folder: 010
# Processing images in folder: 011
# Processing images in folder: 012
# Processing images in folder: 013
# Processing images in folder: 014
# Processing images in folder: 015
# Processing images in folder: 016
# Processing images in folder: 017
# Processing images in folder: 018
# Processing images in folder: 019
# Processing images in folder: 020
# Processing images in folder: 021
# Processing images in folder: 022
# Processing images in folder: 023
# Processing images in folder: 024
# Processing images in folder: 025
# Processing images in folder: 026
# Processing images in folder: 027
# Processing images in folder: 028
# Processing images in folder: 029
# Processing images in folder: 030
# Processing images in folder: 031
# Processing images in folder: 032
# Processing images in folder: 033
# Processing images in folder: 034
# Processing images in folder: 035
# Processing images in folder: 036
# Processing images in folder: 037
# Processing images in folder: 038
# Processing images in folder: 039
# Processing images in folder: 040
# Processing images in folder: 041
# Processing images in folder: 042
# Processing images in folder: 043
# Processing images in folder: 044
# Processing images in folder: 045
# Processing images in folder: 046
# Processing images in folder: 047
# Processing images in folder: 048
# Processing images in folder: 049
# Processing images in folder: 050
# Processing images in folder: 051
# Processing images in folder: 052
# Processing images in folder: 053
# Processing images in folder: 054
# Processing images in folder: 055
# Processing images in folder: 056
# Processing images in folder: 057
# Processing images in folder: 058
# Processing images in folder: 059
# Processing images in folder: 060
# Processing images in folder: 061
# Processing images in folder: 062
# Processing images in folder: 063
# Processing images in folder: 064
# Processing images in folder: 065
# Processing images in folder: 066
# Processing images in folder: 067
# Processing images in folder: 068
# Processing images in folder: 069
# Processing images in folder: 070
# Processing images in folder: 071
# Processing images in folder: 072
# Processing images in folder: 073
# Processing images in folder: 074
# Processing images in folder: 075
# Processing images in folder: 076
# Processing images in folder: 077
# Processing images in folder: 078
# Processing images in folder: 079
# Processing images in folder: 080
# Processing images in folder: 081
# Processing images in folder: 082
# Processing images in folder: 083
# Processing images in folder: 084
# Processing images in folder: 085
# Processing images in folder: 086
# Processing images in folder: 087
# Processing images in folder: 088
# Processing images in folder: 089
# Processing images in folder: 090
# Processing images in folder: 091
# Processing images in folder: 092
# Processing images in folder: 093
# Processing images in folder: 094
# Processing images in folder: 095
# Processing images in folder: 096
# Processing images in folder: 097
# Processing images in folder: 098
# Processing images in folder: 099
# Processing images in folder: 100
# Image processing and saving completed.
